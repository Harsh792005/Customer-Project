# %% [markdown]
# ## Customer Project

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
df = pd.read_csv(r"C:\Users\hp\Downloads\data scince\project1\cust_satisfaction.csv")

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# 2                     satisfied   26             1142                       5
# 3       neutral or dissatisfied   25              562                       2
# 4                     satisfied   61              214                       3
# ...                         ...  ...              ...                     ...
# 103899  neutral or dissatisfied   23              192                       2
# 103900                satisfied   49             2347                       5
# 103901  neutral or dissatisfied   30             1995                       4
# 103902  neutral or dissatisfied   22             1000                       1
# 103903  neutral or dissatisfied   27             1723                       1
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                      4            5                          25
# 1                      3            1                           1
# 2                      4            5                           0
# 3                      3            2                          11
# 4                      4            3                           0
# ...                  ...          ...                         ...
# 103899                 4            2                           3
# 103900                 5            4                           0
# 103901                 4            4                           7
# 103902                 1            1                           0
# 103903                 4            1                           0
#
#         Arrival Delay in Minutes
# 0                           18.0
# 1                            6.0
# 2                            0.0
# 3                            9.0
# 4                            0.0
# ...                          ...
# 103899                       0.0
# 103900                       0.0
# 103901                      14.0
# 103902                       0.0
# 103903                       0.0
#
# [103904 rows x 12 columns]

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103899    False
# 103900    False
# 103901    False
# 103902    False
# 103903    False
# Length: 103904, dtype: bool

# %%
print(df[df.duplicated()])
# Out:
#         Gender      Customer Type   Type of Travel     Class satisfaction  \
# 2741      Male     Loyal Customer  Business travel  Business    satisfied
# 5228      Male  disloyal Customer  Business travel       Eco    satisfied
# 6278    Female  disloyal Customer  Business travel  Business    satisfied
# 7330      Male     Loyal Customer  Business travel  Business    satisfied
# 8405      Male     Loyal Customer  Business travel  Business    satisfied
# ...        ...                ...              ...       ...          ...
# 102110    Male     Loyal Customer  Business travel  Business    satisfied
# 102327    Male     Loyal Customer  Business travel  Business    satisfied
# 102679  Female     Loyal Customer  Business travel  Business    satisfied
# 102801    Male     Loyal Customer  Business travel  Business    satisfied
# 103627    Male     Loyal Customer  Business travel  Business    satisfied
#
#         Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 2741     56             1535                       5                 5
# 5228     20              861                       2                 5
# 6278     21              448                       2                 5
# 7330     49              258                       4                 4
# 8405     53             2149                       4                 4
# ...     ...              ...                     ...               ...
# 102110   45             1389                       5                 5
# 102327   56              444                       5                 5
# 102679   44              862                       5                 5
# 102801   48             3354                       4                 4
# 103627   46              945                       4                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# 2741              3                           0                       0.0
# 5228              2                           0                       0.0
# 6278              2                           0                       0.0
# 7330              4                           0                       0.0
# 8405              3                           0                       0.0
# ...             ...                         ...                       ...
# 102110            3                           0                       0.0
# 102327            5                           1                       0.0
# 102679            5                           0                       0.0
# 102801            4                           0                       0.0
# 103627            4                           0                       0.0
#
# [172 rows x 12 columns]

# %%
df = df.drop_duplicates()
print(df)
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# 2                     satisfied   26             1142                       5
# 3       neutral or dissatisfied   25              562                       2
# 4                     satisfied   61              214                       3
# ...                         ...  ...              ...                     ...
# 103899  neutral or dissatisfied   23              192                       2
# 103900                satisfied   49             2347                       5
# 103901  neutral or dissatisfied   30             1995                       4
# 103902  neutral or dissatisfied   22             1000                       1
# 103903  neutral or dissatisfied   27             1723                       1
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                      4            5                          25
# 1                      3            1                           1
# 2                      4            5                           0
# 3                      3            2                          11
# 4                      4            3                           0
# ...                  ...          ...                         ...
# 103899                 4            2                           3
# 103900                 5            4                           0
# 103901                 4            4                           7
# 103902                 1            1                           0
# 103903                 4            1                           0
#
#         Arrival Delay in Minutes
# 0                           18.0
# 1                            6.0
# 2                            0.0
# 3                            9.0
# 4                            0.0
# ...                          ...
# 103899                       0.0
# 103900                       0.0
# 103901                      14.0
# 103902                       0.0
# 103903                       0.0
#
# [103732 rows x 12 columns]

# %%
print("Before:", len(df))
df.drop_duplicates(inplace=True)
print("After:", len(df))
# Out:
# Before: 103732
# After: 103732

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103899    False
# 103900    False
# 103901    False
# 103902    False
# 103903    False
# Length: 103732, dtype: bool

# %%
t = df[df.duplicated()]

# %%
t
# Out:
# Empty DataFrame
# Columns: [Gender, Customer Type, Type of Travel, Class, satisfaction, Age, Flight Distance, Inflight entertainment, Baggage handling, Cleanliness, Departure Delay in Minutes, Arrival Delay in Minutes]
# Index: []

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Type of Travel'].unique()
# Out:
# <StringArray>
# ['Personal Travel', 'Business travel']
# Length: 2, dtype: str

# %%
df['Class'].unique()
# Out:
# <StringArray>
# ['Eco Plus', 'Business', 'Eco']
# Length: 3, dtype: str

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df['satisfaction'].unique()
# Out:
# <StringArray>
# ['neutral or dissatisfied', 'satisfied']
# Length: 2, dtype: str

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction',
#        'Age', 'Flight Distance', 'Inflight entertainment', 'Baggage handling',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='str')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='satisfaction', data=df)
plt.show()

# %%
sns.countplot(x='Gender', data=df)
plt.show()

# %%
sns.histplot(df['Age'])
plt.show()

# %%
sns.countplot(x='Customer Type', data=df)
plt.show()

# %%
sns.scatterplot(x='Age',y='Cleanliness',data=df)
plt.show()

# %%
sns.histplot(x='Age',y='Cleanliness',data=df)
plt.show()

# %%
sns.countplot(
    x='Class',
    hue='satisfaction',
    data=df
)
plt.show()

# %%
sns.countplot(
    x='Type of Travel',
    hue='satisfaction',
    data=df
)

plt.show()

# %%
numeric = df.select_dtypes(include='number')

sns.heatmap(
    numeric.corr(),
    annot=True
)

plt.show()
